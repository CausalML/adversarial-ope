# %%
from environments.toy_env import ToyEnv
from utils.policy_evaluation import evaluate_policy
from policies.generic_policies import EpsilonSmoothPolicy
from policies.toy_env_policies import ThresholdPolicy
from utils.offline_dataset import OfflineRLDataset
from models.fnn_nuisance_model import FeedForwardNuisanceModel
from models.fnn_critic import FeedForwardCritic
from learners.iterative_sieve_critic import IterativeSieveLearner

s_threshold = 2.0
gamma = 0.9
adversarial_lambda = 4.0
batch_size = 1024
num_sample = 10000

env = ToyEnv(s_init=s_threshold, adversarial=False)
pi_e = ThresholdPolicy(env, s_threshold=s_threshold)
pi_e_name = "pi_e"

dataset_path_train = "tmp_dataset/train_data"
dataset_path_test = "tmp_dataset/test_data"

# %%
## build datasets and save them

pi_base = ThresholdPolicy(env, s_threshold=1.5)
pi_b = EpsilonSmoothPolicy(env, pi_base=pi_base, epsilon=0.1)

dataset = OfflineRLDataset()
dataset.sample_new_trajectory(env=env, pi=pi_b, burn_in=1000,
                              num_sample=num_sample, thin=10)

test_dataset = OfflineRLDataset()
test_dataset.sample_new_trajectory(env=env, pi=pi_b, burn_in=1000,
                                   num_sample=num_sample, thin=10)

dataset.apply_eval_policy(pi_e_name, pi_e)
test_dataset.apply_eval_policy(pi_e_name, pi_e)

dataset.save_dataset(dataset_path_train)
test_dataset.save_dataset(dataset_path_test)

# %%
## double check that dataset is loadable and looks correct

dataset_tmp = OfflineRLDataset.load_dataset(dataset_path_train)
dl = dataset_tmp.get_batch_loader(batch_size=10)
# for i, batch in enumerate(dl):
#     for k, v in batch.items():
#         print(k, v.shape)
#         print(v)
#     print("")
#     if i > 10:
#         break
batch = next(iter(dl))
f = env.init_basis_func(batch["s"], batch["a"])
print(f.shape)
print(f.sum(1))
for i in range(len(f)):
    print(f[i])

# %%
## train model on q / xi / eta moments

s_dim = env.get_s_dim()
num_a = env.get_num_a()

model_do = 0.05
model_config = {
    "s_embed_dim": 32,
    "s_embed_layers": [32],
    "s_embed_do": model_do,
    "a_embed_dim": 32,
    "sa_feature_dim": 64,
    "sa_feature_layers": [64],
    "sa_feature_do": model_do,
    "q_layers": [64, 64],
    "q_do": model_do,
    "beta_layers": [64, 64],
    "beta_do": model_do,
    "w_layers": [64, 64],
    "w_do": model_do,
    "eta_layers": [64, 64],
    "eta_do": model_do,
}
# model_config = {
#     "s_embed_dim": 16,
#     "s_embed_layers": [16],
#     "s_embed_do": model_do,
#     "a_embed_dim": 16,
#     "sa_feature_dim": 32,
#     "sa_feature_layers": [32],
#     "sa_feature_do": model_do,
#     "q_layers": [32, 16],
#     "q_do": model_do,
#     "beta_layers": [32, 16],
#     "beta_do": model_do,
#     "w_layers": [32, 16],
#     "w_do": model_do,
#     "eta_layers": [32, 16],
#     "eta_do": model_do,
# }
model = FeedForwardNuisanceModel(s_dim=s_dim, num_a=num_a, gamma=gamma,
                                 config=model_config)
critic_class = FeedForwardCritic
critic_do = 0.05
critic_config = {
    "s_embed_dim": 8,
    "s_embed_layers": [8],
    "s_embed_do": critic_do,
    "a_embed_dim": 8,
    "critic_layers": [16],
    "critic_do": critic_do,
}
critic_kwargs = {
    "s_dim": s_dim,
    "num_a": num_a,
    "config": critic_config
}

learner_1 = IterativeSieveLearner(
    nuisance_model=model,
    gamma=gamma,
    adversarial_lambda=adversarial_lambda,
    train_q_xi=True, train_eta=True, train_w=True,
)

s_init, a_init = env.get_s_a_init(pi_e)
dl_test = test_dataset.get_batch_loader(batch_size=batch_size)
evaluate_pv_kwargs = {
    "s_init": s_init, "a_init": a_init,
    "dl_test": dl_test, "pi_e_name": pi_e_name,
}
learner_1.train(
    dataset, pi_e_name=pi_e_name, verbose=True,
    init_basis_func=env.bias_basis_func, num_init_basis=1,
    # init_basis_func=env.flexible_basis_func,
    # num_init_basis=env.get_num_init_basis_func(),
    # model_lr=1e-4,
    # num_init_basis=env.get_num_init_basis_func(),
    evaluate_pv_kwargs=evaluate_pv_kwargs, critic_class=critic_class,
    s_init=s_init, critic_kwargs=critic_kwargs,
)
model.save_model("tmp_model")
# Out:
# MODEL: iter 1
# Starting val loss: -8.623429298400879, per moment: tensor([  96.0244,   46.5482, 6275.6685, 6407.6978])
#
# MODEL: iter 1, epoch 2
# mean train loss: -15.511043548583984, per moment: tensor([  93.2458,   45.3112, 6261.0142, 6401.4785])
# mean val loss: 5.4278082847595215, per moment: tensor([  96.0653,   46.5931, 6261.8955, 6400.4746])
# NEW BEST
#
# MODEL: iter 1, epoch 4
# mean train loss: 0.9242706298828125, per moment: tensor([  93.0692,   45.2108, 6247.6152, 6376.1353])
# mean val loss: 11.378922462463379, per moment: tensor([  95.8779,   46.4904, 6248.2573, 6378.4458])
#
# MODEL: iter 1, epoch 6
# mean train loss: 7.144765377044678, per moment: tensor([  93.0005,   45.2024, 6256.5679, 6395.1606])
# mean val loss: -0.6231111884117126, per moment: tensor([  95.8075,   46.4809, 6256.9648, 6395.0879])
# NEW BEST
#
# MODEL: iter 1, epoch 8
# mean train loss: 5.194064140319824, per moment: tensor([  93.0157,   45.2021, 6265.2798, 6402.6890])
# mean val loss: -1.9781579971313477, per moment: tensor([  95.8178,   46.4780, 6265.5498, 6405.8472])
# NEW BEST
#
# MODEL: iter 1, epoch 10
# mean train loss: 1.2648710012435913, per moment: tensor([  92.9966,   45.1532, 6261.8394, 6393.6787])
# mean val loss: 6.028151988983154, per moment: tensor([  95.7988,   46.4251, 6262.0112, 6392.0874])
#
# MODEL: iter 1, epoch 12
# mean train loss: 6.0092363357543945, per moment: tensor([  93.0121,   45.1590, 6251.4512, 6383.1387])
# mean val loss: 1.8445576429367065, per moment: tensor([  95.8135,   46.4320, 6251.6182, 6382.8154])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 72
#      67 dl_test = test_dataset.get_batch_loader(batch_size=batch_size)
#      68 evaluate_pv_kwargs = {
#      69     "s_init": s_init, "a_init": a_init,
#      70     "dl_test": dl_test, "pi_e_name": pi_e_name,
#      71 }
# ---> 72 learner_1.train(
#      73     dataset, pi_e_name=pi_e_name, verbose=True,
#      74     # init_basis_func=env.bias_basis_func, num_init_basis=1,
#      75     init_basis_func=env.flexible_basis_func,
#      76     num_init_basis=env.get_num_init_basis_func(),
#      77     model_lr=1e-4,
#      78     # num_init_basis=env.get_num_init_basis_func(),
#      79     evaluate_pv_kwargs=evaluate_pv_kwargs, critic_class=critic_class,
#      80     s_init=s_init, critic_kwargs=critic_kwargs,
#      81 )
#      82 model.save_model("tmp_model")
#
# File ~/Documents/research/ms-research/adversarial-rl/learners/iterative_sieve_critic.py:141, in IterativeSieveLearner.train(self, dataset, pi_e_name, critic_class, critic_kwargs, s_init, init_basis_func, num_init_basis, evaluate_pv_kwargs, batch_size, gamma_tik, gamma_0, total_num_iterations, val_frac, model_max_epoch, model_min_epoch, model_grad_clip, model_eval_freq, model_max_no_improve, model_lr, model_reg_alpha, model_reg_alpha_final, model_max_epoch_final, model_min_epoch_final, model_eval_freq_final, model_max_no_improve_final, model_lr_final, model_grad_clip_final, critic_max_epoch, critic_min_epoch, critic_eval_freq, critic_max_no_improve, critic_lr, verbose, device)
#     137 # now do iterative updates with weighted objective
#     138 for iter_i in range(1, total_num_iterations+1):
#     139
#     140     # do a training update on model
# --> 141     self.update_model(
#     142         critic=critic, dl=dl, dl_2=dl_2, dl_val=dl_val,
#     143         s_init=s_init, pi_e_name=pi_e_name, gamma_0=gamma_0,
#     144         gamma_tik=gamma_tik, min_num_epoch=model_min_epoch,
#     145         max_num_epoch=model_max_epoch,
#     146         max_no_improve=model_max_no_improve,
#     147         eval_freq=model_eval_freq, grad_clip=model_grad_clip,
#     148         reg_alpha=model_reg_alpha,
#     149         iter_i=iter_i, lr=model_lr, verbose=verbose, device=device,
#     150     )
#     151     if verbose and (evaluate_pv_kwargs is not None):
#     152         self.print_policy_value_estimates(**evaluate_pv_kwargs)
#
# File ~/Documents/research/ms-research/adversarial-rl/learners/iterative_sieve_critic.py:274, in IterativeSieveLearner.update_model(self, critic, dl, dl_2, dl_val, pi_e_name, max_num_epoch, s_init, min_num_epoch, max_no_improve, grad_clip, eval_freq, lr, gamma_0, gamma_tik, iter_i, reg_alpha, device, verbose, eig_threshold)
#     270 # print(rho_f_1)
#     271 # print(rho_f_2)
#     272 # loss = 0.5 * torch.einsum("xy,x,y->", omega, rho_f_1, rho_f_2)
#     273 loss = 0.5 * torch.einsum("xy,x,y->", omega, rho_f_1, rho_f_2)
# --> 274 loss_reg = reg_alpha * self.get_batch_l2_reg(
#     275     batch=batch, pi_e_name=pi_e_name
#     276 )
#     277 # print(loss)
#     279 model_optim.zero_grad()
#
# File ~/Documents/research/ms-research/adversarial-rl/learners/abstract_learner.py:93, in AbstractLearner.get_batch_l2_reg(self, batch, pi_e_name)
#      91 pi_ss = batch[f"pi_ss::{pi_e_name}"]
#      92 r = batch["r"]
# ---> 93 q, v, _, eta, w  = self.model.get_all(s, a, ss, pi_ss)
#      94 reg_sum = 0
#      95 if self.train_q_xi:
#
# File ~/Documents/research/ms-research/adversarial-rl/models/fnn_nuisance_model.py:159, in FeedForwardNuisanceModel.get_all(self, s, a, ss, pi_ss)
#     158 def get_all(self, s, a, ss, pi_ss):
# --> 159     return self.net(
#     160         s, a, ss, pi_ss, calc_q=True, calc_v=True, calc_xi=True,
#     161         calc_eta=True, calc_w=True,
#     162     )
#
# File ~/.virtualenvs/adversarial-rl/lib/python3.8/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/.virtualenvs/adversarial-rl/lib/python3.8/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/Documents/research/ms-research/adversarial-rl/models/fnn_nuisance_model.py:90, in FFNuisanceModule.forward(self, s, a, ss, pi_ss, calc_q, calc_v, calc_xi, calc_eta, calc_w)
#      88 pi_ss_embed = self.a_embed_net(pi_ss)
#      89 ss_pi_ss_concat = torch.cat([ss_embed, pi_ss_embed], dim=1)
# ---> 90 ss_pi_ss_features = self.sa_feature_net(ss_pi_ss_concat)
#      91 # v = self.scale * torch.sigmoid(self.q_net(ss_pi_ss_features) / 10.0)
#      92 v = self.pos_head(self.q_net(ss_pi_ss_features))
#
# File ~/.virtualenvs/adversarial-rl/lib/python3.8/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/.virtualenvs/adversarial-rl/lib/python3.8/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/Documents/research/ms-research/adversarial-rl/utils/neural_nets.py:22, in FFNet.forward(self, input)
#      21 def forward(self, input):
# ---> 22     return self.ff_net(input)
#
# File ~/.virtualenvs/adversarial-rl/lib/python3.8/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/.virtualenvs/adversarial-rl/lib/python3.8/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/.virtualenvs/adversarial-rl/lib/python3.8/site-packages/torch/nn/modules/container.py:215, in Sequential.forward(self, input)
#     213 def forward(self, input):
#     214     for module in self:
# --> 215         input = module(input)
#     216     return input
#
# File ~/.virtualenvs/adversarial-rl/lib/python3.8/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/.virtualenvs/adversarial-rl/lib/python3.8/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/.virtualenvs/adversarial-rl/lib/python3.8/site-packages/torch/nn/modules/activation.py:682, in GELU.forward(self, input)
#     681 def forward(self, input: Tensor) -> Tensor:
# --> 682     return F.gelu(input, approximate=self.approximate)
#
# KeyboardInterrupt:

# %%
## load pre-sampled datasets / model (for skipping first stage)

dataset = OfflineRLDataset.load_dataset(dataset_path_train)
test_dataset = OfflineRLDataset.load_dataset(dataset_path_test)
model = FeedForwardNuisanceModel.load_model("tmp_model")

# %%
s_dim = env.get_s_dim()
num_a = env.get_num_a()

model_do = 0.05
model_config = {
    "s_embed_dim": 16,
    "s_embed_layers": [16],
    "s_embed_do": model_do,
    "a_embed_dim": 16,
    "sa_feature_dim": 32,
    "sa_feature_layers": [32],
    "sa_feature_do": model_do,
    "q_layers": [32, 16],
    "q_do": model_do,
    "beta_layers": [32, 16],
    "beta_do": model_do,
    "w_layers": [32, 16],
    "w_do": model_do,
    "eta_layers": [32, 16],
    "eta_do": model_do,
}
model = FeedForwardNuisanceModel(s_dim=s_dim, num_a=num_a, gamma=gamma,
                                 config=model_config)

# %%
## train the w model

s_dim = env.get_s_dim()
num_a = env.get_num_a()

critic_class = FeedForwardCritic
critic_do = 0.05
critic_config = {
    "s_embed_dim": 8,
    "s_embed_layers": [8],
    "s_embed_do": critic_do,
    "a_embed_dim": 8,
    "critic_layers": [16],
    "critic_do": critic_do,
}
critic_kwargs = {
    "s_dim": s_dim,
    "num_a": num_a,
    "config": critic_config
}

learner_2 = IterativeSieveLearner(
    nuisance_model=model,
    gamma=gamma, adversarial_lambda=adversarial_lambda,
    train_q_xi=True, train_eta=False, train_w=False,
)
s_init, a_init = env.get_s_a_init(pi_e)
dl_test = test_dataset.get_batch_loader(batch_size=batch_size)
evaluate_pv_kwargs = {
    "s_init": s_init, "a_init": a_init,
    "dl_test": dl_test, "pi_e_name": pi_e_name,
}
learner_2.train(
    dataset, pi_e_name=pi_e_name, verbose=True,
    init_basis_func=env.init_basis_func, num_init_basis=env.get_num_init_basis_func(),
    evaluate_pv_kwargs=evaluate_pv_kwargs, critic_class=critic_class,
    s_init=s_init, critic_kwargs=critic_kwargs, model_lr=1e-3, model_eval_freq=5,
    model_max_epoch=500, model_grad_clip=None, model_grad_clip_final=None,
    model_min_epoch=50, model_max_no_improve=3, total_num_iterations=20,
    model_reg_alpha=1e-3, model_reg_alpha_final=1e-3, critic_eval_freq=5,
    gamma_tik=1e-3, gamma_0=1e-3,
)
model.save_model("tmp_model_w")

# %%
dl = iter(dataset.get_batch_loader(batch_size=10))
batch = next(dl)
eta = model.get_eta(s=batch["s"], a=batch["a"])
w = model.get_w(s=batch["s"])
print(f"eta: {eta}")
print(f"w: {w}")

for batch in dataset.get_batch_loader(batch_size=1000):
    eta = model.get_eta(s=batch["s"], a=batch["a"])
    w = model.get_w(s=batch["s"])
    print(f"eta mean: {eta.mean()}")
    print(f"w mean: {w.mean()}")
    print("")

# %%
## evaluate model using 3 policy value estimators

s_init, a_init = env.get_s_a_init(pi_e)
dl_test = test_dataset.get_batch_loader(batch_size=batch_size)

q_pv = model.estimate_policy_val_q(
    s_init=s_init, a_init=a_init, gamma=gamma
)
w_pv = model.estimate_policy_val_w(dl=dl_test)
dr_pv = model.estimate_policy_val_dr(
    s_init=s_init, a_init=a_init, pi_e_name=pi_e_name, dl=dl_test,
    adversarial_lambda=adversarial_lambda, gamma=gamma
)
print(f"EVALUATING FINAL BEST MODEL:")
print(f"Q-estimated v(pi_e): {q_pv}")
print(f"W-estimated v(pi_e): {w_pv}")
print(f"DS/DV-estimated v(pi_e): {dr_pv}")
print("")

env_eval = ToyEnv(s_init=s_threshold, adversarial=True,
                    adversarial_lambda=adversarial_lambda)
pi_e_val = evaluate_policy(env_eval, pi_e, gamma, min_prec=1e-4)
print(f"true v(pi_e): {pi_e_val}")
print("")
